# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import glob
import warnings
warnings.filterwarnings("ignore")

# %%
path = 'data/'
pendentes = pd.read_table(path + 'p.txt', index_col=None, header=0)

pendentes.head()
# Out:
#    municipio  sucursal  localidade  unidade_operativa  zona  \
# 0        0.0     100.0      1140.0                NaN   NaN
# 1        0.0     100.0      1130.0                NaN   NaN
# 2        0.0     100.0      1120.0                NaN   NaN
# 3        0.0     100.0      1150.0                NaN   NaN
# 4        0.0     100.0      1240.0                NaN   NaN
#
#   acometida_retirada  numero_cliente  numero_ordem tipo_ordem tipo_servico  \
# 0                  A        44039521      62196031        ATC          ACI
# 1                  A        52564756      62196272        ATC          ACI
# 2                  A        41052117      62196396        ATC          ACI
# 3                  A          934324      62196644        ATC          ACI
# 4                  A        51213504      62196745        ATC          ACI
#
#    ... valor_cargo eletricista empreiteira estado_cliente_cod  \
# 0  ...         NaN         NaN         NaN                0.0
# ...

# %%
pendentes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30281 entries, 0 to 30280
# Data columns (total 33 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   municipio            30278 non-null  float64
#  1   sucursal             30278 non-null  float64
#  2   localidade           30278 non-null  float64
#  3   unidade_operativa    0 non-null      float64
#  4   zona                 0 non-null      float64
#  5   acometida_retirada   30281 non-null  object
#  6   numero_cliente       30281 non-null  int64
#  7   numero_ordem         30281 non-null  int64
#  8   tipo_ordem           30281 non-null  object
#  9   tipo_servico         30281 non-null  object
#  10  des_servico          30281 non-null  object
#  11  etapa                30280 non-null  object
#  12  descricao_etapa      30280 non-null  object
#  13  cod_retorno          2635 non-null   object
#  14  descricao_retorno    2624 non-null   object
# ...
