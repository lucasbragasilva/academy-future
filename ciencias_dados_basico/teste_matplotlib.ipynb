# %%
import matplotlib.pyplot as grafico

# %%
meses = ['Jan', 'Fev', 'Mar', 'Abr', 'Mai', 'Jun']
tMed = [30, 31, 27, 26, 22, 18]

# %%
grafico.ylabel('temp / ºC')
grafico.xlabel('Mês', color = 'blue')
grafico.axis(ymin = 0, ymax = 40)
grafico.title('Temperaturas Médias Mensais')
#grafico.plot(meses, tMed, label = 'Temperaturas', marker = 'o')
grafico.bar(meses, tMed, label = 'Temperaturas', color = 'gray')
grafico.legend()
#grafico.grid(True)

grafico.show()

# %%
lista = []
tupla = ()
dicionario = {'nome': ['a','b'], 'nota1': [1,2]}

print(type(lista))
print(type(tupla))
print(type(dicionario))
print(dicionario)
# Out:
# <class 'list'>
# <class 'tuple'>
# <class 'dict'>
# {'nome': ['a', 'b'], 'nota1': [1, 2]}

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
x = [1, 2, 3, 4, 5, 6, 7]
y = [50, 51, 52, 48, 47, 49, 46]

# %%
plt.xlabel('Day')
plt.ylabel('Temperature')
plt.title('Weather')
plt.plot(x, y, color = 'green', linewidth = 5, linestyle = 'dotted')

# %%
plt.plot(x, y, 'rD')

# %%
plt.plot(x, y, color = '#888888', marker = 'D', linestyle = '', markersize = 20)

# %%
plt.plot(x, y, color = 'green', alpha=0.5) #alpha é a transparencia

# %%
days = [1,2,3,4,5,6,7]
max_t = [32,51,52,48,47,49,46]
min_t = [43,42,40,44,33,35,37]
avg_t = [45,48,48,46,40,42,41]

# %%
plt.xlabel("Days")
plt.ylabel("Temperatura")
plt.title("Weather")

plt.plot(days, max_t, label = "Max")
plt.plot(days, min_t, label = "Min")
plt.plot(days, avg_t, label = "Avg")

plt.legend(loc = "best", shadow = True, fontsize = "small")

plt.grid()

# %%
# blood_sugar = [113, 85, 150, 149, 88, 93, 115, 135, 80, 77, 82, 129]
blood_sugar_men = [113, 85, 90, 150, 149, 88, 93, 115, 135, 80, 77, 82, 129]
blood_sugar_women = [67, 98, 89, 120, 133, 150, 84, 69, 89, 79, 120, 112, 100]

plt.xlabel('Sugar range')
plt.ylabel('Total no of patients')
plt.title('Blood sugar analysis')
plt.hist([blood_sugar_men, blood_sugar_women], bins = [80, 100, 125, 150], rwidth = 0.95, color=['green', 'orange'], 
         label = ['men',' women'] ) #histtype='step' orientatiton='horizontal'
plt.legend()

# %%
exp_vals = [1400, 600, 300, 410, 250]
exp_labels = ["Home Rent", "Food", "Phone/Internet Bill", "Car ", "Other Utilities"]

# %%
plt.axis("equal")
plt.pie(exp_vals, labels = exp_labels, radius = 1.5, autopct = '%0.1F%%', shadow = True, explode = [0, 0.1, 0.1, 0, 0], 
        startangle=100)
plt.savefig("piechart.png", bbox_inches = "tight", pad_inches = 2, transparent = True)
plt.show()
